# %% [markdown]
# # CS 431: Data-Intensive Distributed Computing (Fall 2026)
# # Assignment 2: ETL
#
# This assignment focuses on common ETL and data cleaning tasks that a data scientist or data engineer might need to do.
#
# We'll be working with a dataset from the [Steam platform](https://store.steampowered.com/), built from the Steam API.
# Imagine that you're on the data team, and at a high level, the product team wants to understand the Steam marketplace: applications, reviews, genres, etc.
# If you're not already familiar with Steam, the [Wikipedia page](https://en.wikipedia.org/wiki/Steam_(service)) provides a reasonable intro.
#
# The dump we want you to work with is `steam.dump`, available at `https://cs.uwaterloo.ca/~jimmylin/cs431-2026f/steam.dump` with MD5 checksum `b83bc49384eed83262de9524addcc27a`.
# This is a modified version of the original [Steam Dataset 2025: Multi-Modal Gaming Analytics dataset on Kaggle](https://www.kaggle.com/datasets/crainbramp/steam-dataset-2025-multi-modal-gaming-analytics).
#
# You're expected to use a coding agent to help you with this assignment.
# However, you are ultimately responsible for and accountable for _everything_, including design decisions, quality checks, bugs, edge cases, interpretation of the results, etc.
# You are also responsible for _understanding_ what the coding agent is doing.

# %% [markdown]
# The first task is to restore the database from the `steam.dump` file above.
#
# Do this in your environment.
#
# + Make sure you use the user `cs431`.
# + Make sure you use the database name `steam_2025`.
#
# Your coding agent can help.

# %% [markdown]
# In the cell below we've defined some boilerplate to connect to the database.
# You'll be using the `read_sql` function throughout the assignment.
#
# Just run the cell.
#
# _(Note that if the port is unavailable, switch to a different port, but remember to change the port back in your final assignment submission.)_

# %%
import os
from urllib.parse import quote_plus

import pandas as pd
from sqlalchemy import create_engine, text

POSTGRES_HOST = os.getenv("POSTGRES_HOST", "localhost")
POSTGRES_PORT = int(os.getenv("POSTGRES_PORT", "5432"))
POSTGRES_DB = os.getenv("POSTGRES_DB", "steam_2025")
POSTGRES_USER = os.getenv("POSTGRES_USER", "cs431")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD", "")

password_fragment = f":{quote_plus(POSTGRES_PASSWORD)}" if POSTGRES_PASSWORD else ""
DATABASE_URL = (f"postgresql+psycopg://{quote_plus(POSTGRES_USER)}{password_fragment}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}")

engine = create_engine(DATABASE_URL)

def read_sql(query, params=None):
    with engine.connect() as connection:
        return pd.read_sql(text(query), connection, params=params)

def execute_sql(statement, params=None):
    with engine.begin() as connection:
        connection.execute(text(statement), params or {})

# %% [markdown]
# To make sure everything is properly configured, run the following query:

# %%
read_sql("SELECT current_database(), current_user, version() AS postgres_version")

# %% [markdown]
# You should see `steam_2025` as `current_database` and `cs431` as `current_user`.
# If you're getting errors, debug.
# Don't continue until the above query works.
#
# Note that when we are grading your assignment, we will make sure that the `steam_2025` database already exists.
# That is, you can already assume that a fresh dump (`steam.dump`) has been restored.
# You don't need to have code in this assignment notebook that performs the restore.

# %% [markdown]
# ## 1. Understanding the Database

# %% [markdown]
# Take some time to understand the database and the data it contains.
#
# "Talk" to the database via your agent and "poke around".
# This documentation might be helpful: [PostgreSQL Database Schema Documentation](https://github.com/vintagedon/steam-dataset-2025/blob/main/docs/postgresql-database-schema.md).
#
# The goal here is for you to become acquainted with the database and the data it contains, for example:
#
# + Understand what the various tables are and what they model.
# + Understand how the various tables are "connected together" via primary key (PK) / foreign key (FK) relationships.
#
# You can test your own understanding by asking various questions (of your own construction) about the data, and trying to answer those questions by issuing SQL queries.
# Your agent can be very helpful, and can in fact translate most of your questions into the corresponding SQL queries (perfectly fine to use your agent this way).
# However, it is _your_ responsibility to understand the queries and the structure of the database.
#
# There is nothing specific to "do" here beyond the explorations outlined above.

# %% [markdown]
# Let's start with some warm-up exercises: consider the game "Counter-Strike" (with this exact name).
#
# In the questions below, either write the SQL query that answers the question, or answer the question directly in prose.
# (What to do should be obvious from context.)
# For questions about Counter-Strike, your SQL queries must directly reference its name.
#
# **Q1.1: What's the short description of the game?**

# %%
## acell_21_1 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# **Q1.2: How many fields capture the description of the game and closely related information?**
#
# _Commentary: yes, it is common for real-world databases to have duplicate, (partially) overlapping, and confusingly named fields..._

# %% [markdown]
# // acell_21_2 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# **Q1.3: How many total reviews are there for Counter-Strike?**

# %%
## acell_21_3 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# **Q1.4: How many reviews are there for Counter-Strike in this dataset?**

# %%
## acell_21_4 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# **Q1.5: Why might there be this discrepancy?**

# %% [markdown]
# // acell_21_5 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# **Q1.6: Who are the developers?**

# %%
## acell_21_6 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# _That's interesting. Only one developer. So, wait..._
#
# **Q1.7: What game has the most developers?**

# %%
## acell_21_7 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# Wow, that's a lot of developers.
#
# What's going on here?
# _(Make sure you understand; nothing to specifically write here.)_

# %% [markdown]
# **Q1.8: What genres is "Counter-Strike" classified under?**

# %%
## acell_21_8 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# Okay, that's it for warm-ups.

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# By now you should have a pretty good "feel" for the data.
#
# In this section, we will walk you through some common data cleaning tasks.
# The primary focus will be on auditing data quality, i.e., identifying possible issues with the data.
# You won't actually be asked to clean the data (we'll do the cleaning for you).

# %% [markdown]
# ### 2.1 Primary Keys

# %% [markdown]
# Let's start by looking at the primary keys in the tables.
#
# For each of the tables in `SOURCE_TABLES`, show the number of records (rows).
# Your code should print out a bunch of lines, each in the format `table,count`.

# %%
## acell_22_1 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

SOURCE_TABLES = [
    "applications",
    "reviews",
    "developers",
    "publishers",
    "genres",
    "categories",
    "platforms",
    "application_developers",
    "application_publishers",
    "application_genres",
    "application_categories",
    "application_platforms",
]

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# In a well-designed schema, each table should have a primary key.
# For each of the tables below, identify what the primary key _should_ be.
# That is, replace `fake_key` in each entry below.
#
# When you run the cell, the output should be in the form of `table,count,unique_count`:
#
# + `count` is the number of rows in each table.
# + `unique_count` is the cardinality of the primary key.
#
# How should these values relate?
# _(Nothing to explicitly write, just answer for yourself)_

# %%
## acell_22_2 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

## Fill in the correct keys below.
TABLES_TO_PKS = {
    "applications": "fake_key",
    "reviews": "fake_key",
    "developers": "fake_key",
    "publishers": "fake_key",
    "genres": "fake_key",
    "categories": "fake_key",
    "platforms": "fake_key",
}

######### END STUDENT CODE #########

for table, pk in TABLES_TO_PKS.items():
    counts = read_sql(f"""
        SELECT COUNT(*) AS total,
               COUNT(DISTINCT "{pk}") AS unique_count
        FROM "{table}"
    """).iloc[0]

    print(f"{table},{counts['total']},{counts['unique_count']}")

# %% [markdown]
# From the `table,count,unique_count` lines above you should be able to identify tables with potential issues.
#
# In the cell below, fill in the stub code.
# `TABLES_WITH_ISSUES` is a dictionary:
#
# + the key is the name of a table that is potentially problematic.
# + its value is an SQL query that demonstrates the problem.
#
# Note that the `TABLES_WITH_ISSUES` stub has three entries (representing three potentially problematic tables).
# There may be more or fewer problematic tables, but the variable `TABLES_WITH_ISSUES` should be correctly populated.
# That is, the number of entries should equal the number of tables that you have identified as potentially problematic.

# %%
## acell_22_3 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

## Fill in the table names and queries below.

TABLES_WITH_ISSUES = {
    "table 1": """

-- SQL query 1

    """,
    "table 2": """

-- SQL query 2

    """,
    "table 3": """

-- SQL query 3

    """    
}

######### END STUDENT CODE #########

for table, query in TABLES_WITH_ISSUES.items():
    print(f"## Issues with table '{table}':")
    print(read_sql(query).to_string(index=False))
    print()

# %% [markdown]
# In prose, identify the problematic table(s) and explain the issues.

# %% [markdown]
# // acell_22_4 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# ### 2.2 The Reviews Table

# %% [markdown]
# Let's focus on the `reviews` table.
#
# What's the field in this table that identifies which application the review is for?

# %% [markdown]
# // acell_22_5 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# This field should "point to" applications that actually exist, i.e., there should be no "dangling pointers".
# That is, every review should reference an application that actually exists.
#
# Is this the case?
# Write an SQL query below to either show that it is the case, or identify cases that are problematic.

# %%
## acell_22_6 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# In prose, identify and explain the issue.

# %% [markdown]
# // acell_22_7 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# Next, there's something odd about the `timestamp_created` field.
# One common way to identify issues is to plot a histogram of values.
# That is, what are the values that `timestamp_created` can take, and how frequently does each value appear?
#
# Below, show this distribution using `matplotlib`.
# One plot is fine.
# More than one plot is also fine.
# When I run the cell, it should be obvious what the issues are.

# %%
## acell_22_8 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

# Use matplotlib: we've imported it for you.
import matplotlib.pyplot as plt

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# In prose, explain the issue.

# %% [markdown]
# // acell_22_9 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# Next, there's something odd about the relationship between `timestamp_created` and `timestamp_updated`.
#
# Can you identify what it is?
# Write an SQL query that shows the issue.

# %%
## acell_22_0 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# In prose, explain the issue.

# %% [markdown]
# // acell_22_a (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# ### 2.3 The Applications Table

# %% [markdown]
# Let's now turn our attention to the `applications` table.

# %% [markdown]
# As you've done above already, one common way to identify issues with fields is to plot a distribution of their values.
# In many cases, the field itself constrains the range of valid values.
# For example, take the `discount_percent`.
#
# What range of values can it take?
# Identify what's wrong with certain entries in the `applications` table with respect to this field.
#
# In the cell below, show the issue.
# That is, when we run the cell, it should clearly identify the issue.
# (You can decide on the method... e.g., a plot, an SQL query, ...)

# %%
## acell_22_b (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# In prose, explain the issue you identified above.

# %% [markdown]
# // acell_22_c (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# Let's do one more.
#
# In the `applications` table, identify another issue for a particular field.
#
# Same as above: In the cell below, show the issue. That is, when we run the cell, it should clearly identify the issue. (You can decide on the method... e.g., a plot, an SQL query, ...)

# %%
## acell_22_d (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# In prose, explain the issue you identified above.

# %% [markdown]
# // acell_22_e (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# Okay, this concludes the data auditing part of the assignment.
#
# Once you've figured out what the issues are, fixing them (i.e., doing the actual cleaning) is the next step.
#
# Note that fixing the data issues can be time-consuming, and often requires making judgment calls.
# For example, impossible values:
# What do you do?
# Remove them?
# Change them to something reasonable?
# Something else?
# This must be "thought through" on a case-by-case basis.

# %% [markdown]
# ## 3. Skipping Ahead to the "Gold" Tables

# %% [markdown]
# Now we're going to skip ahead...
# We've done a lot of the data cleaning for you behind the scenes and are going to give you the "gold" tables.
#
# Where does the term come from?
# It's a common way to describe the progression of data cleaning; see [this blog post](https://www.databricks.com/blog/what-is-medallion-architecture) as an example.
#
# We created a dump of the "gold" tables in `steam_gold.dump`, which can be found at `https://cs.uwaterloo.ca/~jimmylin/cs431-2026f/steam_gold.dump` with MD5 checksum `3e36aa64b723fdf2b7825735ae0959f5`.
#
# Load the gold dump (i.e., restore) into the same database (`steam_2025`) under the same user `cs431`.
# Your database should now have more tables.
# Nothing else should change.
# Your existing tables should remain.
#
# Run the following query to confirm:

# %%
sql_query = """

    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'gold' AND table_type = 'BASE TABLE'
    ORDER BY table_name

"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# You should see a bunch of new tables.
# If you don't, you've done something wrong.
# Stop and debug.

# %% [markdown]
# For each table in the `gold` schema, print the number of records (rows).
# The output should be `table,count`.

# %%
## acell_23_1 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# Take some time to understand the gold tables.
# The goal here is for you to become acquainted with the gold tables in the same way as you did with the raw data.
#
# Describe _briefly_ what we did to create the gold tables from raw data.
# For calibration, we're looking for a short paragraph at the most.

# %% [markdown]
# // acell_23_2 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# ### 3.1 Issues with Release Dates

# %% [markdown]
# The truth is that data cleaning is a continuous, if not endless, task.
#
# Have we really cleaned the data?
# Let's find out...

# %% [markdown]
# Let's look at the `release_date` in `gold.fact_game_marketplace`.
#
# Draw a histogram of `release_date`, using release year on the horizontal axis and number of games on the vertical axis.
# As before, use `matplotlib`.

# %%
## acell_23_3 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

import matplotlib.pyplot as plt

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

# %% [markdown]
# Oh no!
#
# Describe what the problem is below.

# %% [markdown]
# // acell_23_4 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# ### 3.2 Populating Review Counts

# %% [markdown]
# Next, let's look at the review counts.
#
# Run the following cell.

# %%
sql_query = """

    SELECT appid, name, review_count, positive_review_count, negative_review_count
    FROM gold.fact_game_marketplace
    ORDER BY appid
    LIMIT 10

"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# That doesn't seem right... Let's check the review table.
#
# Specifically, let's compare totals.
# We'll compute `stored_total` (the sum of game-level `review_count`) and `actual_total` (the number of rows in `gold.reviews`).
#
# Run the following cell.

# %%
sql_query = """

SELECT
    (
        SELECT SUM(review_count)::bigint
        FROM gold.fact_game_marketplace
    ) AS stored_total,
    (
        SELECT COUNT(*)
        FROM gold.reviews
    ) AS actual_total;

"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# What's going on?

# %% [markdown]
# // acell_23_5 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# Well, let's fix the issue then.
#
# Your task: populate `review_count`, `positive_review_count`, and `negative_review_count` in `gold.fact_game_marketplace`.
#
# Where do these values come from?
# From `gold.reviews`.
# Count all reviews in the table: count positive votes with `voted_up IS TRUE` and negative votes with `voted_up IS FALSE`.
#
# Update existing game rows, retain zero counts for games without reviews, and leave review rates and average playtime unchanged.
# Do not deduplicate or otherwise clean reviews here.
# Running the update again must give the same counts.
#
# Do it using SQL manipulations below.

# %%
## acell_23_6 (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

print("Done!")

# %% [markdown]
# Did it work?
#
# Run the following query to find out.

# %%
sql_query = """

SELECT
    SUM(review_count)::bigint AS review_count,
    SUM(positive_review_count)::bigint AS positive_review_count,
    SUM(negative_review_count)::bigint AS negative_review_count
FROM gold.fact_game_marketplace;

"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# Do you get what you expect?
# _(No need to explicitly respond)_
#
# (We will run a few checks ourselves.)

# %% [markdown]
# ### 3.3 Genre Normalization

# %% [markdown]
# For the final exercise, let's start by checking a few things...

# %% [markdown]
# Answer the following question:
#
# **Q3.1: What genres is "Counter-Strike" classified under (using the gold tables)?**

# %%
## acell_23_a (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# **Q3.2: What genres is "Counter-Strike 2" classified under (using the gold tables)?**

# %%
## acell_23_b (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# **Q3.3: Wait, what's going on? Describe below.**
#
# _(Shouldn't both games belong to the same genre?)_

# %% [markdown]
# // acell_23_c (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# We should normalize the genres.
#
# + Let's normalize all the variants of `genre_id` 122 to 122.
# + Let's normalize all the variants of `genre_id` 44 to 44.
#
# It's your job to figure out the list of ids that should normalize to 122 and 44, respectively, to fill in the lists below.

# %%
## acell_23_d (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

######### BEGIN STUDENT CODE #########

# 1, 2, 3, 4 are fake entries: replace with real entries.
ids_for_122 = [1, 2, 3, 4]
ids_for_44 = [1, 2, 3, 4]

######### END STUDENT CODE #########

print(f"These are the ids that should be normalized to 122: {ids_for_122}")
print(f"These are the ids that should be normalized to  44: {ids_for_44}")

# %% [markdown]
# Okay, let's do the normalization, but using Spark.
# (Instead of SQL, per above.)
#
# Assuming you've set up your computing environment [based on the course instructions](https://lintool.github.io/cs431-2026f/software.html), the following code snippet should "just work" to initialize Spark.
#
# If it doesn't, you'll need to debug your computing environment.
# The environment should be exactly the same as the setup for assignment 1.

# %%
import findspark, os

# TODO: Set path accordingly - below it is hard-coded to my machine
os.environ["SPARK_HOME"] = "/Users/jimmylin/workspace/teaching2026/spark-4.2.0-bin-hadoop3"
findspark.init()

# %% [markdown]
# Start a local Spark session:

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("Assignment2")
    .master("local[*]")            # Use all local cores
    .config("spark.ui.showConsoleProgress", "true")
    .config("spark.jars.packages", "org.postgresql:postgresql:42.7.7")
    .getOrCreate()
)

spark

# %% [markdown]
# Note that in this case we're explicitly including a JDBC driver for PostgreSQL.

# %% [markdown]
# Let's write a Spark job to do the normalization.
#
# Your code should read from the `gold.bridge_game_genre` table and write to a new table called `gold.bridge_game_genre2`:
#
# + Use JDBC.
# + Perform the normalization as above, i.e., whenever you encounter an id that should map back to 122, do it.
# + Same with id 44.
# + Drop `gold.bridge_game_genre2` if it already exists.
#
# Write the code below.

# %%
## acell_23_e (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

import os
from pyspark.sql import SparkSession, functions as F

######### BEGIN STUDENT CODE #########

######### END STUDENT CODE #########

print("Done!")

# %% [markdown]
# Now let's see if you've fixed the problem.
#
# Answer using the correct SQL query.
#
# **Q3.4: How many games are classified as "Action", based on the original `gold.bridge_game_genre` table?**

# %%
## acell_23_f (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# Answer using the correct SQL query.
#
# **Q3.5: How many games are classified as "Action", based on the normalized `gold.bridge_game_genre2` table?**

# %%
## acell_23_g (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# And let's check the specific games again.
#
# **Q3.6: What genres is "Counter-Strike" classified under (now using the normalized `gold.bridge_game_genre2` table)?**

# %%
## acell_23_h (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# And:
#
# **Q3.7: What genres is "Counter-Strike 2" classified under (now using the normalized `gold.bridge_game_genre2` table)?**

# %%
## acell_23_i (keep this id for tracking purposes)
# TODO: Write your code below, but do not remove any lines already in this cell.

sql_query = """
-- BEGIN STUDENT CODE

-- END STUDENT CODE
"""

print(read_sql(sql_query).to_string(index=False))

# %% [markdown]
# The normalization should have worked!
#
# (We will run a few checks ourselves.)

# %% [markdown]
# ## 4. Reflection on AI Collaboration

# %% [markdown]
# Reflect on your use of AI to complete this assignment.
#
# Complete this log honestly.
# This is primarily for your own benefit.
# We'll read it, but it won't be graded.
#
# Potential things to reflect on:
#
# + What I asked Codex to do.
# + What worked.
# + What failed or needed correction.
# + What I changed or checked myself.
# + One place where my domain knowledge or lecture knowledge mattered.
# + One prompt I would write differently next time.

# %% [markdown]
# // acell_24_1 (keep this id for tracking purposes)
#
# **Answer:** Replace with your answer.

# %% [markdown]
# ## 5. Assignment Submission

# %% [markdown]
# For assignment submission details, see [the course homepage](https://lintool.github.io/cs431-2026f/assignments/assignment2.html).
# Make sure you conform to the requirements articulated there.
